# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Dia.csv')

# %%
df
# Out:
#     Season  Humidity  Temperature Grass YouCanPlant
# 0   Summer      True           20  Hard          No
# 1   Summer     False           24  Soft          No
# 2   Summer      True           16  Soft         Yes
# 3   Autumn     False           10  Soft          No
# 4   Autumn      True            9  Hard          No
# 5   Autumn     False            3  Hard          No
# 6   Winter      True          -10  Hard          No
# 7   Winter     False          -14  Soft          No
# 8   Winter      True          -23  Hard          No
# 9   Spring      True            3  Hard          No
# 10  Spring      True           12  Soft         Yes
# 11  Spring      True           23  Hard         Yes
# 12  Autumn     False           -1  Hard         Yes
# 13  Autumn     False            6  Soft          No
# 14  Summer     False            8  Hard         Yes
# 15  Winter     False          -27  Soft         Yes
# 16  Autumn      True            5  Hard         Yes
# ...

# %%
translates = {
    'Season' : ['Summer','Autumn','Winter','Spring'],
    'Humidity' : [True, False],
    'Temperature' : [-23, -14, -10, 3, 9, 10, 12, 16, 20, 23, 24, 26],
    'Grass' : ['Hard','Soft'],
    'YouCanPlant' : ['No','Yes'],
}

# %%
df.Season.replace({k:v for k,v in zip(translates['Season'], range(len(translates['Season'])))}, inplace = True)
df.Humidity = df.Humidity.astype('int32')
df.Temperature.replace({k:v for k,v in zip(translates['Temperature'], range(len(translates['Temperature'])))}, inplace = True)
df.Grass.replace({k:v for k,v in zip(translates['Grass'], range(len(translates['Grass'])))}, inplace = True)
df.YouCanPlant.replace({k:v for k,v in zip(translates['YouCanPlant'], range(len(translates['YouCanPlant'])))}, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       32 non-null     int64
#  1   Humidity     32 non-null     int32
#  2   Temperature  32 non-null     int64
#  3   Grass        32 non-null     int64
#  4   YouCanPlant  32 non-null     int64
# dtypes: int32(1), int64(4)
# memory usage: 1.2 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       32 non-null     int64
#  1   Humidity     32 non-null     int32
#  2   Temperature  32 non-null     int64
#  3   Grass        32 non-null     int64
#  4   YouCanPlant  32 non-null     int64
# dtypes: int32(1), int64(4)
# memory usage: 1.2 KB

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
dtc = DecisionTreeClassifier(criterion = 'entropy', max_depth = 15, min_samples_leaf=2)
dtc.fit(df.drop('YouCanPlant', axis = 1), df['YouCanPlant'])
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=15, min_samples_leaf=2)

# %%
fig = plt.figure(figsize = (20, 20))
plot_tree(dtc, feature_names = df.columns, class_names=['Можно садить', 'Нельзя садить'])
# Out:
# [Text(0.5, 0.9166666666666666, 'Temperature <= 6.5\nentropy = 1.0\nsamples = 32\nvalue = [16, 16]\nclass = Можно садить'),
#  Text(0.25, 0.75, 'Temperature <= -0.5\nentropy = 0.976\nsamples = 22\nvalue = [13, 9]\nclass = Можно садить'),
#  Text(0.125, 0.5833333333333334, 'Season <= 0.5\nentropy = 0.946\nsamples = 11\nvalue = [4, 7]\nclass = Нельзя садить'),
#  Text(0.0625, 0.4166666666666667, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Нельзя садить'),
#  Text(0.1875, 0.4166666666666667, 'Temperature <= -20.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = Можно садить'),
#  Text(0.125, 0.25, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = Можно садить'),
#  Text(0.25, 0.25, 'Temperature <= -6.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = Нельзя садить'),
#  Text(0.1875, 0.08333333333333333, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Можно садить'),
# ...

# %%
dtc.score(df.drop('YouCanPlant', axis = 1), df['YouCanPlant'])
# Out:
# 0.78125

# %%
test = pd.DataFrame({'Season': [0], 'Humidity': [False], 'Temperature': [30], 'Grass': [0]})
test
# Out:
#    Season  Humidity  Temperature  Grass
# 0       0     False           30      0

# %%
dtc.predict(test)
# Out:
# array([0], dtype=int64)
