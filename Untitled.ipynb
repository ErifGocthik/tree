# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Dia.csv')

# %%
df
# Out:
#     Season  Humidity  Temperature Grass YouCanPlant
# 0   Summer      True           20  Hard          No
# 1   Summer     False           24  Soft          No
# 2   Summer      True           16  Soft         Yes
# 3   Autumn     False           10  Soft          No
# 4   Autumn      True            9  Hard          No
# 5   Autumn     False            3  Hard          No
# 6   Winter      True          -10  Hard          No
# 7   Winter     False          -14  Soft          No
# 8   Winter      True          -23  Hard          No
# 9   Spring      True            3  Hard          No
# 10  Spring      True           12  Soft         Yes
# 11  Spring      True           23  Hard         Yes

# %%
translates = {
    'Season' : ['Summer','Autumn','Winter','Spring'],
    'Humidity' : [True, False],
    'Temperature' : [-23, -14, -10, 3, 9, 10, 12, 16, 20, 23, 24, 26],
    'Grass' : ['Hard','Soft'],
    'YouCanPlant' : ['No','Yes'],
}

# %%
df.Season.replace({k:v for k,v in zip(translates['Season'], range(len(translates['Season'])))}, inplace = True)
df.Humidity = df.Humidity.astype('int32')
df.Temperature.replace({k:v for k,v in zip(translates['Temperature'], range(len(translates['Temperature'])))}, inplace = True)
df.Grass.replace({k:v for k,v in zip(translates['Grass'], range(len(translates['Grass'])))}, inplace = True)
df.YouCanPlant.replace({k:v for k,v in zip(translates['YouCanPlant'], range(len(translates['YouCanPlant'])))}, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       12 non-null     int64
#  1   Humidity     12 non-null     int32
#  2   Temperature  12 non-null     int64
#  3   Grass        12 non-null     int64
#  4   YouCanPlant  12 non-null     int64
# dtypes: int32(1), int64(4)
# memory usage: 560.0 bytes

# %%
df
# Out:
#     Season  Humidity  Temperature  Grass  YouCanPlant
# 0        0         1            8      0            0
# 1        0         0           10      1            0
# 2        0         1            7      1            1
# 3        1         0            5      1            0
# 4        1         1            4      0            0
# 5        1         0            3      0            0
# 6        2         1            2      0            0
# 7        2         0            1      1            0
# 8        2         1            0      0            0
# 9        3         1            3      0            0
# 10       3         1            6      1            1
# 11       3         1            9      0            1

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
dtc = DecisionTreeClassifier(criterion = 'entropy', max_depth = 15)
dtc.fit(df.drop('YouCanPlant', axis = 1), df['YouCanPlant'])
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=15)

# %%
fig = plt.figure(figsize = (10, 10))
plot_tree(dtc, feature_names = df.columns, class_names=translates['YouCanPlant'])
# Out:
# [Text(0.3333333333333333, 0.875, 'Temperature <= 5.5\nentropy = 0.811\nsamples = 12\nvalue = [9, 3]\nclass = No'),
#  Text(0.16666666666666666, 0.625, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No'),
#  Text(0.5, 0.625, 'Temperature <= 7.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = Yes'),
#  Text(0.3333333333333333, 0.375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Yes'),
#  Text(0.6666666666666666, 0.375, 'Season <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = No'),
#  Text(0.5, 0.125, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No'),
#  Text(0.8333333333333334, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Yes')]
